# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("spotify dataset.csv")
df
# Out:
#                      track_id  \
# 0      6f807x0ima9a1j3VPbc7VN
# 1      0r7CVbZTWZgbTCYdfa2P31
# 2      1z1Hg7Vb0AhHDiEmnDE79l
# 3      75FpbthrwQmzHlBJLuGdC7
# 4      1e8PAfcKUYoKkxPhrHqw4x
# ...                       ...
# 32828  7bxnKAamR3snQ1VGLuVfC1
# 32829  5Aevni09Em4575077nkWHz
# 32830  7ImMqPP3Q1yfUHvsdn7wEo
# 32831  2m69mhnfQ1Oq6lGtXuYhgX
# 32832  29zWqhca3zt5NsckZqDf6c
#
#                                               track_name      track_artist  \
# 0      I Don't Care (with Justin Bieber) - Loud Luxur...        Ed Sheeran
# 1                        Memories - Dillon Francis Remix          Maroon 5
# 2                        All the Time - Don Diablo Remix      Zara Larsson
# 3                      Call You Mine - Keanu Silva Remix  The Chainsmokers
# 4                Someone You Loved - Future Humans Remix     Lewis Capaldi
# ...                                                  ...               ...
# ...

# %%
print("Shape of dataset:", df.shape)
print("\nColumn names:\n", df.columns.tolist())
print("\nInfo:\n")
print(df.info())
print("\nFirst 5 rows:\n")
print(df.head())
# Out:
# Shape of dataset: (32833, 23)
#
# Column names:
#  ['track_id', 'track_name', 'track_artist', 'track_popularity', 'track_album_id', 'track_album_name', 'track_album_release_date', 'playlist_name', 'playlist_id', 'playlist_genre', 'playlist_subgenre', 'danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo', 'duration_ms']
#
# Info:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32833 entries, 0 to 32832
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   track_id                  32833 non-null  object
#  1   track_name                32828 non-null  object
#  2   track_artist              32828 non-null  object
#  3   track_popularity          32833 non-null  int64
#  4   track_album_id            32833 non-null  object
#  5   track_album_name          32828 non-null  object
# ...

# %%
print("Missing values per column:\n", df.isnull().sum())
df_clean=df.dropna()
df_clean = df_clean.drop_duplicates(subset=['track_name','track_artist'])
irrelevant_columns = [
    'track_id', 'track_name', 'track_artist', 'track_album_id',
    'track_album_name', 'track_album_release_date', 'playlist_name',
    'playlist_id', 'playlist_subgenre','playlist_genre'
]
df_cluster = df_clean.drop(columns=irrelevant_columns)

print("\nCleaned dataset shape:", df_cluster.shape)
# Out:
# Missing values per column:
#  track_id                    0
# track_name                  5
# track_artist                5
# track_popularity            0
# track_album_id              0
# track_album_name            5
# track_album_release_date    0
# playlist_name               0
# playlist_id                 0
# playlist_genre              0
# playlist_subgenre           0
# danceability                0
# energy                      0
# key                         0
# loudness                    0
# mode                        0
# speechiness                 0
# acousticness                0
# instrumentalness            0
# liveness                    0
# valence                     0
# tempo                       0
# duration_ms                 0
# dtype: int64
#
# Cleaned dataset shape: (26229, 13)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style='whitegrid')
plt.figure(figsize=(16,10))
features=['danceability','energy', 'key','loudness','mode', 'speechiness',
            'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo', 'duration_ms']
for i, feature in enumerate(features):
  plt.subplot(4,3,i+1)
  sns.histplot(df_cluster[feature],kde=True,bins=30)
  plt.title(f'Distribution of {feature}')

plt.tight_layout()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure(figsize=(12, 10))
corr_matrix=df_cluster.corr()
sns.heatmap(corr_matrix, annot=True, fmt=".2f", cmap="coolwarm", square=True)
plt.title("Correlation Matrix of Audio Features")
plt.show()

# %%
from sklearn.preprocessing import StandardScaler
numeric_features=df_cluster.select_dtypes(include=['float64','int64'])
scalar=StandardScaler()
scaled_data=scalar.fit_transform(numeric_features)
scaled_df=pd.DataFrame(scaled_data,columns=numeric_features.columns)
scaled_df.head()
# Out:
#    track_popularity  danceability    energy       key  loudness      mode  \
# 0          1.138702      0.648253  1.187898  0.172536  1.377905  0.879175
# 1          1.181685      0.497099  0.641278  1.555792  0.612647  0.879175
# 2          1.310634      0.146697  1.269079 -1.210719  1.116373 -1.137430
# 3          0.880803      0.442134  1.263667  0.449188  1.002978  0.879175
# 4          1.267651     -0.025069  0.738696 -1.210719  0.709984  0.879175
#
#    speechiness  acousticness  instrumentalness  liveness   valence     tempo  \
# 0    -0.488036     -0.348473         -0.400305 -0.804252  0.049627  0.038340
# 1    -0.691234     -0.479290         -0.382588  1.060253  0.795230 -0.781094
# 2    -0.334186     -0.448353         -0.400207 -0.518536  0.454383  0.111578
# 3    -0.065191     -0.672422         -0.400265  0.082299 -0.977176  0.035369
# 4    -0.704781     -0.444376         -0.400305 -0.689199  0.931569  0.110390
#
#    duration_ms
# 0    -0.501257
# 1    -1.025744
# ...

# %%
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

inertia=[]
K=range(1,16)

for k in K:
  kmeans=KMeans(n_clusters=k, random_state=42)
  kmeans.fit(scaled_df)
  inertia.append(kmeans.inertia_)

plt.figure(figsize=(8,5))
plt.plot(K,inertia,'bo-')
plt.xlabel('Number of clusters(k)')
plt.ylabel('Inertia (Sum of squared distances)')
plt.title('Elbow method for optimal K')
plt.grid(True)
plt.show()

# %%
kmeans=KMeans(n_clusters=5, random_state=42)
kmeans.fit(scaled_df)

scaled_df['cluster']=kmeans.labels_
print(scaled_df['cluster'].value_counts())

scaled_df.head()
# Out:
# cluster
# 4    8271
# 2    6662
# 1    5304
# 0    3750
# 3    2242
# Name: count, dtype: int64
#    track_popularity  danceability    energy       key  loudness      mode  \
# 0          1.138702      0.648253  1.187898  0.172536  1.377905  0.879175
# 1          1.181685      0.497099  0.641278  1.555792  0.612647  0.879175
# 2          1.310634      0.146697  1.269079 -1.210719  1.116373 -1.137430
# 3          0.880803      0.442134  1.263667  0.449188  1.002978  0.879175
# 4          1.267651     -0.025069  0.738696 -1.210719  0.709984  0.879175
#
#    speechiness  acousticness  instrumentalness  liveness   valence     tempo  \
# 0    -0.488036     -0.348473         -0.400305 -0.804252  0.049627  0.038340
# 1    -0.691234     -0.479290         -0.382588  1.060253  0.795230 -0.781094
# 2    -0.334186     -0.448353         -0.400207 -0.518536  0.454383  0.111578
# 3    -0.065191     -0.672422         -0.400265  0.082299 -0.977176  0.035369
# ...

# %%
from sklearn.decomposition import PCA
import seaborn as sns
import matplotlib.pyplot as plt

pca=PCA(n_components=2)
pca_data=pca.fit_transform(scaled_df.drop('cluster',axis=1))

pca_df=pd.DataFrame(data=pca_data, columns=['PCA1','PCA2'])
pca_df['cluster']=scaled_df['cluster']

plt.figure(figsize=(10,6))
sns.scatterplot(x='PCA1',y='PCA2',hue='cluster',data=pca_df,palette='Set2',s=60)
plt.xlabel('PCA component 1')
plt.ylabel('PCA component 2')
plt.legend(title='Cluster')
plt.grid(True)
plt.show()

# %%
df_full=df_clean.copy()
df_full['cluster']=kmeans.labels_

def recommend(song_name,df,n_recommendations):
  matches = df[df['track_name'].str.lower().str.contains(song_name.lower(), na=False)]
  if matches.empty:
    return f"Song '{song_name}' not found"
  if(len(matches)>1):
    print("Multiple matches found, please pick one: ")
    for i,row in matches[['track_name','track_artist']].reset_index(drop=True).iterrows():
      print(f"{i+1}. {row['track_name']}-{row['track_artist']}")
    choice=int(input("Enter your choice: "))
    if(choice<0 or choice>len(matches)):
      return "Invalid choice"
    song=matches.iloc[choice-1]
    print(f"your choice: {song['track_name']} - {song['track_artist']}")
  else:
    song=matches.iloc[0]
    print(f"your choice: {song['track_name']} - {song['track_artist']}")
  cluster_label=song['cluster']
  similar_songs=df[(df['cluster']==cluster_label)&(df['track_name'].str.lower()!=song_name.lower())]
  recommended=similar_songs.sample(n=min(n_recommendations,len(similar_songs)))
  return recommended[['track_name', 'track_artist', 'playlist_genre', 'track_popularity']]

SongName=input("Enter the song to which you want similar recommendations: ")
num=int(input("Enter number of recommendations: "))
recommend(SongName, df_full,num)
# Out:
# Enter the song to which you want similar recommendations: call you
# Enter number of recommendations: 5
# Multiple matches found, please pick one:
# 1. Call You Mine - Keanu Silva Remix-The Chainsmokers
# 2. Call You Mine-The Chainsmokers
# 3. Call You Mine - Asketa & Natan Chaim Remix-The Chainsmokers
# 4. Call You (feat. Nasri of MAGIC!)-Cash Cash
# 5. Call You Home - Faul & Wad Ad Remix-Kelvin Jones
# 6. Call Your Name-A.M.T
# 7. Can I Call You Tonight?-Dayglow
# 8. I Can Call You-Portrait
# 9. I Call Your Name-Debra Killings
# Enter your choice: 2
# your choice: Call You Mine - The Chainsmokers
#                                               track_name track_artist  \
# 28612                                       Enlighten Me    DubVision
# 9942                                               Grain       Getter
# 30471                                         불타오르네 FIRE          BTS
# 13601  I Don't Want to Miss a Thing - From the Touchs...    Aerosmith
# ...

# %%
df_full.to_csv("spotify_dataset_cleaned.csv", index=False)
